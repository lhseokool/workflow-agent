# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate


llm = ChatOllama(model="qwen3:0.6b")

# 프롬프트
prompt = ChatPromptTemplate.from_template("{topic} 에 대하여 간략히 설명해 줘.")
chain = prompt | llm | StrOutputParser()
answer = chain.invoke({"topic": "deep learning"})

print(answer)
# Out:
# /var/folders/ws/j3s8hg595q58z3yq7r3j29rw0000gn/T/ipykernel_8045/1705726521.py:6: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   llm = ChatOllama(model="qwen3:0.6b")
# <think>
# Okay, the user wants a brief explanation of deep learning. Let me start by recalling the basics. Deep learning is a subset of machine learning, right? It's about neural networks with multiple layers. So, I need to explain that it's built on layers of interconnected nodes, which make it powerful for complex tasks.
#
# I should mention that it's used in areas like image recognition, speech processing, and natural language understanding. Maybe give an example like image recognition with CNNs. Also, it's different from simple linear models. Oh, and it's data-driven, so it's trained on large datasets. Need to keep it concise, maybe 5-6 sentences. Avoid jargon, but still make sure the explanation is clear and covers the key points.
# </think>
#
# Deep learning는 뉴런망을 통해 학습되는 모델로, 여러층의 연결이 있는 기반을 가진 분야로 설명됩니다. 이는 흐름형 모델(예: CNN)이나 뉴럴망을 통해 복잡한 문제를 해결하는 능력을 가진 모델입니다. 그의 핵심은 데이터를 기반으로 학습하며, 뉴런의 연결을 통해 입력데이터를 입력하고, 학습 과정에서 모델이 오류를 줄이고 성능을 향상시키는 방식으로, 인공지능, 자연어 처리, 영상 인식 등 다양한 분야에서 활용됩니다.
